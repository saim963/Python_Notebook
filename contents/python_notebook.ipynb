# %%
#basic syntax
print("Hello World")

# %% [markdown]
# Variable:

# %%
num = 34
name = 'Charlie'
alive = True

# %%
#data types in python
#int, float, string, boolean
#operators:
#Arithematic operators: + - * / // % **
#comparision operators: == != > < >= <=
#Logical Operators: and or not
#Assignment operators: = += -= *= /=

# %%
print('This statement is printed output')

# %%
user_name = input("What is your name: ")
print(user_name)

# %% [markdown]
# #Control Flow
#
# if , elif, else : Executes code conditionally

# %%
score = int(input("your marks: "))
if score >= 90:
  print("A")
elif score >=80:
  print("B")
elif score >=70:
  print("C")
else:
  print('F')

# %%
#for loop

for el in "alphanso":
  print(el)

# %%
for el in range(2,9):
  if el>5:
    break
  print(el)

# %%
#While loop
count = 0
while count<3:
  print(f'count is {count}')
  count +=1

# %%
#break and continue: Modify the loop behaviour

for i in range(10):
  if i == 9:
    break #stop the loop when i is 5
  if i%2==0:
    continue  #skipping the even numbers
  print(i)

# %%
#Functions:

def foo():
  print("Heloo moto")

foo()

# %%
#parameters and arguments

def greet(name):
  print(f"Hello Mr. {name}")

greet("John")

# %%
#return values
def sum_two(a,b):
  return a+b

print(sum_two(5,6))

# %% [markdown]
# #### List:
#
# - Lists are ordered mutable collection of items
# - They can contain items of different data types

# %%
lst = ['hey',1,1.25,'C']
print(lst,type(lst))

# %%
names = ['Saim','Gorge','Ron']
print(type(names))

# %%
#Accessing list items
fruits = ['Apple','Kiwi','Banana','Mango']
#Slicing
print(fruits[::-1])
print(fruits[2:4])

# %%
#Modify the list elements
fruits[-1] = 'Guava' #-1 is the last item in list
print(fruits)

# %%
#List methods
fruits.append("Orange") #add an item to the end
fruits.insert(-1,'Mango') #means “place the item at that index,” which shifts the existing item at that position (and all following items) to the right

# %%
print(fruits)

# %%
fruits.insert(1,'new')
print(fruits)

# %%
for fruit in fruits:
  print(fruit)

# %%
#Iterating with index
for index,fruit in enumerate(fruits):
  print(index,fruit)

# %%
#List comprehension
lst=[]
for x in range(10):
  lst.append(x**2)
print(lst)

# %%
[x**2 for x in range(10) if x%2==0]

# %%
#List comprehension basically has 2 things what we want as output and what is the kind of operation that we are doing
[x**3 for x in range(1,11)]

# %% [markdown]
# #### List Comprehension
#
# Basic Syntax: [expression for item in iterable]
#
# With Conditional Logic: [expression for item in iterable if condition]
#
# Nested List Comprehension: [expression for item1 in iterable1 for item2 in iterable2]

# %%
#Basic List comprehension
square = [num**2 for num in range(10)]
print(square)

# %%
#With Conditional Logic
even = [i for i in range(10) if i%2==0]
print(even)

# %%
#Nested List Comprehension
lst1 = [1,2,3,4]
lst2 = ['a','b','c','d']
pair = [(i,j) for i in lst1 for j in lst2]
print(pair)

# %%
#List Comprehension with function calls
words = ['hello','world','python','list']
lengths = [len(word) for word in words]
print(lengths)

# %% [markdown]
# #### Conclusion list
# List comprehensions are powerful and concise way to create a list in Python. They are syntactically compact and can replace more verbose looping constructs. Understanding the syntax of list comprehension will help you write more cleaner and efficient Python code.

# %% [markdown]
# #### Tuples
#
# Many other options are missing in tuple as tuple's main function to hold a fixed collection of items in a fixed order.
#
#  This immutability makes tuples faster and more memory-efficient than lists when you have data that you don't intend to change.

# %%
#Tuple is similar to list but is immutable
my_tuple = (1,2,2,2,3,'f','hi')
two_count = my_tuple.count(2)
print(two_count)
two_index = my_tuple.index(2)
print(two_index)

# %%
nested_tuple = ((1,2,3),("a","b","c"),(0,1))
for sub_tuple in nested_tuple:
  for item in sub_tuple:
    print(item,end=" ")
  print()

# %% [markdown]
# #### Conclusion tuple
# Tuples are versatile and useful in many real-world scenerios where an immutable and ordered collection of items is required. They are commonly used in data structure, function arguments and return values, and as dictionary keys. Understanding how to leverage tuples effectively can improve the efficiency and readability of your Python code.

# %% [markdown]
# #### Sets
#
# Sets are built-in data type in Python used to store collections of unique items. They are unordered, meaning that the elements do not follow the specific order, and they do not allow duplicate elements. Sets are useful for membership tests, eliminating  duplicate entries, and performing mathematical set operations like union, intersection, difference and symmetric difference.

# %%
#Create a set
my_set = {1,2,3,4,5,6,6,6}
print(my_set,type(my_set))

# %%
my_empty_set = set()
print(type(my_empty_set))

# %%
## Basic set operations
## Adding and removing the elements
my_set.add(7)
print(my_set)

my_set.remove(3)
print(my_set)

# %%
my_set.remove(12)

# %%
my_set.discard(12)
print(my_set)

# %%
## pop method
removed_ele = my_set.pop()
print(removed_ele)
print(my_set)

# %%
#Clear all the elements
my_set.clear()
print(my_set)

# %%
## Set membership test
my_set = {1,2,3,4,5}
print(3 in my_set)
print(10 in my_set)

# %%
## Mathematical operations
set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}

## Union
union_set = set1.union(set2)
print(union_set)

## Intersection
intersection_set = set1.intersection(set2)
print(intersection_set)

## Intersection update
set1.intersection_update(set2)
print(set1)

# %%
set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}

## Difference
print(set1.difference(set2))  #set1 minus diff of set2
print(set1)

# %%
## Symmetric diff
print(set1.symmetric_difference(set2))

# %%
##Sets Methods
set1 = {1,2,3,4,5}
set2 = {3,4,5}

# is subset
print(set1.issubset(set2))

# is superset
print(set1.issuperset(set2))

# %% [markdown]
# #### Dictionaries
#
# Dictionaries are unordered collection of items. They store data in key-value pairs. Keys must be unique and immutable (e.g. strings, numbers or tuples),  while values can be of any type.

# %%
##Creating dictionary
dic1 = {'ko':45, 'kp':63, 'kl':79}
dic1

# %%
#accessing dictionary elements
print(dic1['ko'])
print(dic1['kp'])
print(dic1['kl'])

# %%
#Accessing using default get method
student = {"name":'string', "age":'int', "height":'float'}
print(student.get('name'))
print(student.get('gender')) #return none- default

# If i dont find a key, give it a default value just for accessing but no adding
print(student.get('gender','No gender found'))
print(student)

# %%
{x:x**2 for x in range(10)}

# %%
#Modifying dictionary elements
#Dictionaries are mutable so you can add update or delete elements-> at any point of time key needs to be unique
teacher = {"employ_id":"int", "name":"string", "salary":"float", "age":"small_int"}
print("Original teacher dictionary: ",teacher)
teacher_gender = teacher.setdefault("gender",'uk')  #If key already exists, setdefault() returns its current value and does not modify the dictionary.
print("Updated teacher dicationary: ",teacher)

# %%
#Updating and adding to the dicationary
teacher["gender"] = "binary" #updated
print(teacher)
teacher["address"] = "India" #added
print(teacher)
del teacher['gender'] #deleting key-value pair
print(teacher)

# %%
#Common dictionary methods
keys = teacher.keys()
values = teacher.values()
print("keys: ",keys,"values: ",values)
#get all key value pairs
items = teacher.items()
print(items)

# %%
teacher_copy = teacher #Shallow copy
print(teacher)
print(teacher_copy)

# %%
teacher["name"] = "varchar"
print(teacher)
print(teacher_copy)

# %%
#Using copy function
teacher_copy2 = teacher.copy()
teacher["address"] = "IND"
print(teacher)
print(teacher_copy)
print(teacher_copy2)

# %%
#iterating over dictionaries
#you can use loops to iterate

#Iterating over keys
for key in teacher.keys():
  print(key)

# %%
#iterate over values
for val in teacher.values():
  print(val)

# %%
#iterate over items
for item in teacher.items():
  print(item)

# %%
#iterating over the key value pairs
for x,y in teacher.items():
  print(f"{x}:{y}")

# %%
#Nested dictionaries
students = {"student1":{"name":"Sam","age":25,"gender":"Male"},
            "student2":{"name":"John","age":27,"gender":"Male"},
            "student3":{"name":"Peter","age":23,"gender":"Male"}
            }
print(students)

# %%
#Accessing nested dictionary elements
print(students["student2"]["name"])
print(students['student3']['age'])

# %%
#Iterating over nested dictionary
#Nested for loop
for key,val in students.items():
  print(key,val)
  for k,v in val.items():
    print(k,v)

# %%
#Dictionary comprehension
squares = {x:x**2 for x in range(5)}
print(squares)

# %%
#conditional dictionary comprehension
even_sq = {x:x**2 for x in range(10) if x%2==0}
print(even_sq)

# %%
#Practical example- count frequency of items in list
numbers = [9,9,2,3,3,3,3,5,5]
counter = {}
for item in numbers:
  counter[item] = counter.get(item,0)+1
print(counter)

# %%
#Merge 2 dictionaries into one
dict1 = {'a':1,'b':2}
dict2 = {'b':3,'c':4}
merged_dic = {**dict1,**dict2}   # it unpacks the dictionary's key-value pairs as keyword arguments to the function.
print(merged_dic)
#dict2 b overwrites b from dict1

# %%
def greet(name="John Doe"):
  """function for greeting"""
  print(f'Hello {name}, welcome home')

greet()

# %%
def even_odd(num):
  '''This function checks whether the given num is even or odd'''
  return f"{num} is even" if num%2==0 else f"{num} is odd"

even_odd(37.00)

# %%
#function with multiple parameters
def add(a,b):
  return a+b
add(7,9)

# %%
#Variable length arguments
#positional and keyword arguments

def print_numbers(*args):
  for numbers in args:
    print(numbers)

# %%
print_numbers(1,2,3,4,5,6,'Positional arguments',56,565,8998) #positional arguments

# %%
def cal_add(*ar):
  sum = 0
  for x in ar:
    sum += x
  return sum

#Or better way is
def cal_add2(*ar):
  return sum(ar)

# %%
result1 = cal_add(4,5,8,9,10,12,151,448,4646,15,0)
result2 = cal_add2(4,5,8,9,10,12,151,448,4646,15,0)
print(f'Result 1 and 2 are as follows: {result1} and {result2}')

# %%
#Keyword arguments
#all the parameters will be in key value pair
def print_details(**kwargs):
  for key,value in kwargs.items():
    print(f"{key} : {value}")

# %%
print_details(name='Taza', age=67, country='IND')

# %%
print_details('Taza', 67,'IND')

# %%
#combined function positional and keyword agruments
def combined(*args,**kwargs):
  for item in args:
    print(item," from positional")
  for k,v in kwargs.items():
    print(f'{k} : {v} from keyword arguments')

# %%
combined(4,5,6,kw1=11,kw2=12,kw3=13)

# %% [markdown]
# #### Lambda Functions in Python
#
# Lambda functions are small anonymous functions defined using **Lambda** keyword. They can have any number of arguments but only one expression (one logic). They are commonly used for short operations or as arguments to higher-order functions.

# %%
# Syntax
# lambda arguments: expression

# %%
def square(num):      #basic function
  return num*num

sq3 = square(3)
print(sq3)

# %%
square = lambda n:n**2    #much better simple anonymous function which has single expression
print(square(4))

# %%
#calulating sum of arguments
cal_sum = lambda *args: sum(args)
print(cal_sum(4,5,8,9,10,12,151,448,4646,15,0))

# %%
square_pos_args = lambda *args: [n**2 for n in args]   #lambda function with positional arguments
print(square_pos_args(1,2,3))

# %%
##map() -- applies function to all items in a list
numbers= [1,2,3,4,5,6]
list(map(lambda x:x**2, numbers)) #map uses the lazy loading technique

# %%
names = ['saim', 'faheem', 'umair']
list(map(len,names))

# %% [markdown]
# #### The map() function in python
#
# The map() function applies a given function to all items in an input list(or any other iterable) and returns a map oject(an iterator). This is particularly useful for transforming data in a list comprehensively

# %%
def square(n):
  return n**2

sq_lst = list(map(square,numbers))
print(sq_lst)

# %%
#map with lambda function
list(map(lambda x:x**3, numbers))

# %%
#Map multiple iterables
number1 = [1,2,3]
number2 = [4,5,6]
number3 = [7,8,9]
added_numbers = list(map(lambda a,b,c:a+b+c, number1,number2,number3))
print(added_numbers)

# %%
#map() to convert a list of strings to integers
#use map to convert string to integers
str_num = ['1','2','3','4','5']
int_num = list(map(int,str_num))

print(int_num)

# %%
words = ['apple','guava','banana','grape','mango']
upper_word = list(map(str.upper,words))
print(upper_word)

# %%
def get_name(person):
  return person['name']

people = [
    {'name':'Smith','age':25,'salary':0},
    {'name':'Yusuf','age':24,'salary':24000},
    {'name':'Priyansh','age':24,'salary':11000}
]

name_lst = list(map(get_name,people))
print(name_lst)

# %% [markdown]
# #### Conclusion map()
#
# The map() function is a powerful tool for applying transformations to iterable data structures. It can be used with regular functions, lambda functions, and even multiple iterables, providing a versatile approach to data processing in Python. By understanding and utilizing map() you can write more efficient and readable code.

# %% [markdown]
# #### The filter() function in Python
#
# The filter() function constructs an iterator from elements of an iterable for which a function returns true. It is used to filter out items from a list (or any other iterable) based on a condition.

# %%
def even(num):
  if num%2==0:
    return True
  return False

even(25)

# %%
lst_filter = [1,2,3,2,43,44,45,54,56,65,56,57,76,77]
lst_e = [x for x in lst_filter if x%2==0] #by using list comprehension
print(lst_e)

# %%
#Filtering with the help of filter() function
list(filter(even,lst_filter)) #here filter uses the condition from the function and applies it on the iterable

# %%
#filter with lambda function
greater_then_five = list(filter(lambda x:x>5, lst_filter))
print(greater_then_five)

# %%
#filter with lambda function and multiple conditions
even_and_greater_then_five = list(filter(lambda x:x>5 and x%2==0, lst_filter))
print(even_and_greater_then_five)

# %%
#filter with lambda on dictionary
#person is a list of dictionaries
salary_greater_then_0 = list(filter(lambda person:person['salary']>0,people))
print(salary_greater_then_0)

# %% [markdown]
# #### Conclusion filter()
#
# The filter() function is a powerful tool for creating iterators that filter items out of an iterable based on a function. It is commonly used for data cleaning, filtering objects, and removing unwanted elements from lists. By mastering filter(), you can write more concise and efficient code for processing and manipulating collections in python.

# %% [markdown]
# #### Important modules in Python
#
# In python modules and packages help organize and reuse the code. Here's a comprehensive guide on how to import them.

# %%
import math
math.sqrt(99)

# %%
from math import sqrt,pi,pow
print(sqrt(100))
print(pow(7,2))
print(pi)

# %%
import numpy as np
np.array([1,2,3,4,5])

# %%
import sys
sys.path.append('/content')

# %%
import os
print(os.getcwd()) #get current working directory

# %%
from test_dir import test
test.greet()

# %% [markdown]
# #### Conclusion import
#
# To make a package importable we add a file \_\_init\_\_.py in the package then creates other file and imports the module.

# %% [markdown]
# #### Standard Library Overview
#
# Python's standard library is a vast collection of modules and packages that come bundled with Python, provding wide range off functionalities out of box.

# %%
import array
arr = array.array('i',[1,2,32,4])
print(arr)

# %%
## random
import random
print(random.randint(1,11))  #random int between range
print(random.random())  #random float between 0.0 to 1.0
print(random.uniform(2.2,4.5))  #random float value between range
print(random.choice(words))  #for random choice from collection

# %%
#file and directory access
import os
print(os.getcwd()) #get current working directory

# %%
os.mkdir('test_dir')

# %%
#High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')

# %%
#Data sterilization
import json
data = [
    {'name':'Saim','age':25,'salary':0},
    {'name':'Saad','age':24,'salary':24000},
    {'name':'Priyansh','age':24,'salary':11000}
]

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))

# %%
import csv
with open('example.csv',mode='w',newline='') as file:
  writer = csv.writer(file)
  writer.writerow(['name','age'])
  writer.writerow(['Saim',25])

with open('example.csv',mode='r') as file:
  reader = csv.reader(file)
  for row in reader:
    print(row)

# %%
from zoneinfo import ZoneInfo
# 1. Get the current time in UTC (the standard)
utc_now = datetime.now(ZoneInfo("UTC"))

# 2. Define your local timezone.
# For India Standard Time, the IANA name is "Asia/Kolkata".
# For US Eastern Time, it would be "America/New_York".
local_tz = ZoneInfo("Asia/Kolkata")

# 3. Convert the UTC time to your local timezone
local_now = utc_now.astimezone(local_tz)

print(f"Current UTC Time:   {utc_now}")
print(f"Current Local Time: {local_now}")

# %%
from datetime import datetime,timedelta
now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)

# %%
import time
print(time.time())
time.sleep(5)
print(time.time())

# %%
import re
pattern = r'\d+'
text = 'There are 123 apples 34 kiwis'
match = re.search(pattern,text)
print(match.group())

# %% [markdown]
# #### Conclusion standard libraries
#
# Python's Standard Library is extensive and provides tools for almost any task you can think of, from file handling to web services, from data serialization to concurrent execution. Familiarizing yourself with the modules and packages available in the Standard Library can significantly enhance your ability to write efficient and effective Python programs.

# %% [markdown]
# #### File Operation - Read and Write Files
#
# File handling is a crucial part of any programming language. Python provides built-in functions and methods to read from and write to files, both text and binary.

# %%
# Read whole file
with open('example.txt','r') as file:
  content = file.read()
  print(content)

# %%
# Reading file line by line
with open('example.txt','r') as file:
  for line in file:
    print(line.strip()) # strip() removes the new line character

# %%
#Writing a file(Overwriting)
with open('example.txt','w') as file:
  file.write('New line added.\n')  #Entire content is overwritten
  file.write('And another one!\n')

# %%
#Writing a file(Without overwriting)
with open('example.txt','a') as file:
  file.write('Append operation take place.\n')
  file.write('One more line added to the file.\n')

# %%
#Writing a list of line to a file
lines = ['First line\n','Second line\n','These lines are from a list\n']
with open('example.txt','a') as file:
  file.writelines(lines)

# %%
#Binary Files
#Writing to a binary file
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
  file.write(data)

# %%
#Reading to a binary file
with open('example.bin','rb') as file:
  content_b = file.read()
  print(content_b)

# %%
#Read the content from a source text file and copy it to a destination text file
with open('example.txt','r') as source_file:
  content = source_file.read()

with open('destination.txt','a') as des_file:
  des_file.write(content)

# %%
#Read a text file and count the number of lines, words and characters.

line_count = word_count = char_count = 0
with open('destination.txt','r') as file:
  for line in file:
    line_count += 1
    word_count += len(line.split())
    char_count += len(line)

print(f"Lines: {line_count}, Words: {word_count}, Characters: {char_count}")

# %%
#Read a text file and count the number of lines, words and characters.

def count_text_file(file_path):
  with open(file_path,'r') as file:
    lines = file.readlines()
    line_count = len(lines)
    word_count = sum(len(line.split()) for line in lines)
    char_count = sum(len(line) for line in lines)
  return line_count, word_count, char_count

file_path = 'destination.txt'
lines, words, characters = count_text_file(file_path)
print(f"Lines: {lines}, Words: {words}, Characters: {characters}")

# %% [markdown]
# The *w+* mode in python is used for both reading and writing. If the file does not exist, it will be created. If the file exists, its content is truncated(i.e. the file is overwritten).

# %%
#Writing and then reading a file
with open('destination.txt','w+') as file:
  file.write('This is overwritten thing in the file.\n')
  file.write('THis is in destination named file')

  #Move the file cursor to the beginning
  file.seek(0)

  #Read the content of the file
  content = file.read()
  print(content)

# %%
import os
print("Current working directory is: ",os.getcwd())

# %%
#Creatinfg new directory
new_directory = 'package'
os.mkdir(new_directory)
print(f"Directory '{new_directory}' is created")

# %%
#Listing files and directories
items = os.listdir('.')
print(items)

# %%
#Joining Paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)

# %%
path = "example1.txt"
if os.path.exists(path):
  print(f"Path '{path}' exists")
else:
  print(f"Path '{path}' does not exists.")

# %%
#Checking if a Path is a File or Directory
path = 'example.txt'
if os.path.isfile(path):
  print(f"Path '{path}' is a file.")
elif os.path.isdir(path):
  print(f"Path '{path}' is a directory.")
else:
  print(f"Path '{path}' is neither a file nor a directory.")

# %%
# Getting the absolute path
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)

# %% [markdown]
# #### Understanding Exceptions
#
# Exception handling in Python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program. This lesson will cover the basics of exception, including how to use try, except, else and finally blocks.
#
# ### What are Exceptions?
#
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# - ZeroDivisionError : Dividing by Zero
# - FileNotFoundError : File not found
# - ValueError : Invalid value
# - TypeError : Invalid type

# %%
#Exception try, except block

try:
  a = b
except:
  print("The variable has not been assigned")

# %%
try:
  a = b
except NameError as ex:
  print(f"Error: {ex}")

# %%
try:
  x = 1/0
  print(x)
except ZeroDivisionError as zex:
  print("Error: ",zex)

# %%
try:
  result = 1/2
  a=b
except Exception as ex:
  print(ex)

# %%
try:
  num = int(input('Enter a number: '))
  result = 1/num
  print(result)
except Exception as ex:
  print('Error:',ex)

# %%
from typing_extensions import final
#try, except, else and finally block

try:
  num = int(input('Enter a number: '))
  result = 10/num
except ValueError:
  print("That's not a valid number!")
except ZeroDivisionError:
  print("You can't divide by zero!")
except Exception:
  print(Exception)
else:
  print(f"The result is: {result}")
finally:
  print("This is from finally block, it always executes.")

# %% [markdown]
# #### Classes and Objects
#
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modelling real-world scenerios using classes and objects. This lession covers the basics of creating classes and objects, including instance variables and methods.

# %%
# A class is a blueprint of creating objects will have attributes and methods

class Car:
  pass

audi = Car()
bmw = Car()

print(type(audi))

# %%
print(audi)
print(bmw)

# %%
# Instance Variable and Methods
class Dog:
  # Constructor
  def __init__(self,name,age):
    self.name = name
    self.age = age

# Create the objects
dog1 = Dog('Buddy',3)
dog2 = Dog('Doe',2.5)

print(f"First dog is named {dog1.name} and is {dog1.age} years old.")
print(f"The other one is {dog2.name} and she's {dog2.age} years old.")

# %%
# Define a class with instance methods
class Dog:
  #Contructor
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def bark(self):
    print(f"{self.name} is barking")

dog1 = Dog('Buddy',3)
dog1.bark()
dog2 = Dog('Lucy',2)
dog2.bark()

# %%
#Modeling bank account

#Define a class for bank account
class BankAccount:
  def __init__(self,owner,balance=0):
    self.owner = owner
    self.balance = balance

  def deposit(self,amount):
    self.balance += amount #to get access of the balance
    print(f"{amount} is deposited. New balance is: {self.balance}")

  def withdraw(self,amount):
    if amount > self.balance:
      print("Insufficient funds!!")
    else:
      self.balance -= amount
      print(f"{amount} is withdrawn. New balance is: {self.balance}")

  def get_balance(self):
    return self.balance

#Create an object
account = BankAccount("Saim",3700000)
account.get_balance()

# %%
account.deposit(1300000)

# %%
account.withdraw(100000)

# %% [markdown]
# #### Conclusion Classes and Objects
#
# Object-Oriented Programming (OOP) allows you to model real-world scenerios using classes and objects. In this lession, you learned how to create classes and objects, define instance variables and methods, and use them to perform various operations. Understanding these concepts is fundamental to writing effective and maintainable Python code.

# %% [markdown]
# #### Inheritance in Python
#
# Inheritance is a fundamental concept in OOP that allows a class to inherit attributes and methods from another class. This lesson covers single inheritance and multiple inheritance, demonstrating how to create and use them in python.

# %%
#Inheritance (Single Inheritance)

#Parent Class
class Car:
  def __init__(self,model,windows,doors,enginetype):
    self.model = model
    self.windows = windows
    self.doors = doors
    self.enginetype = enginetype

  def drive(self):
    print(f"The person will drive the {self.enginetype} car.")

  def about(self):
    print(f"{self.model} has {self.windows} windows, {self.doors} doors and operates on {self.enginetype}")

# %%
car1 = Car('wagon_r',4,5,'petrol')
car1.drive()
car1.about()

# %%
#Child Class

class Tesla(Car):
  def __init__(self,model,windows,doors,enginetype,is_selfdriving):
    super().__init__(model,windows,doors,enginetype)  #attributes called from parent class
    self.is_selfdriving = is_selfdriving   #only attribute created for tesla

  def selfdriving(self):
    print(f"Tesla {self.model} supports self driving: {self.is_selfdriving}")

# %%
model_3 = Tesla('Model 3',4,5,'electric',True)  #when we call a child class, it passes all the values in the __init__ function of super which passes all the attributes to the parent calss
model_3.selfdriving()   #Tesla Method
model_3.about() #Car method

# %%
#Multiple Inheritance
#When a class inherits from more than one base class

#Base class 1
class Animal:
  def __init__(self, name, habitat):
    self.name = name
    self.habitat = habitat
  def speak(self):
    print(f"Subclasses must implement this method()")

#Base class 2
class Pet:
  def __init__(self, owner):
    self.owner = owner

#Derived class
#Inheriting both the classes
class Dog(Animal,Pet):
  def __init__(self,name,habitat,owner):
    Animal.__init__(self,name,habitat)
    Pet.__init__(self,owner)
  def speak(self):
    return f"{self.name} is barking."

#Creat an object
brownie = Dog("Brownie","shelter","Mohak")
print(f"{brownie.name} lives in the {brownie.habitat} and his owner is {brownie.owner}")
brownie.speak()

# %% [markdown]
# #### Super() in mulitple inheritance
#
# Python’s super() is designed to work with  **Method Resolution Order** (MRO), which ensures that each class in the hierarchy is initialized exactly once, in the correct order.
#
# To make this work, each class must use super() and accept *args and **kwargs:
#
# super() will follow the MRO: Dog → Animal → Pet → object, and each class gets initialized once, cleanly.

# %%
class Animal:
    def __init__(self, name, habitat, *args, **kwargs):
        self.name = name
        self.habitat = habitat
        super().__init__(*args, **kwargs)

class Pet:
    def __init__(self, owner, *args, **kwargs):
        self.owner = owner
        super().__init__(*args, **kwargs)

class Dog(Animal, Pet):
    def __init__(self, name, habitat, owner):
        super().__init__(name, habitat, owner)

# %%
print(Dog.mro())
print(Dog.__mro__)

# %% [markdown]
# #### MRO (Method Resolution Order)
#
# It simply says what's first in line
#
# MRO uses DFS in old version but in newer versions it is complex

# %%
class A:
  age = 10

class B(A):
  pass

class C(A):
  age = 1

class D(B,C):
  pass

print(D.age)
#lets check the order, checking through all the classes lastly the base class is checked.
print(D.mro())
print(D.__mro__)

# %% [markdown]
# #### Polymorphism
#
# Polymorphism is a core concept in Object Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. It provides a way to perform a single action in different forms. Polymorphism is typically achieved through method overriding and interfaces.

# %% [markdown]
# #### Method Overriding
#
# Method overriding allows a child class to provide a specific implementation of a method that is already defined in its parent class.

# %%
#Base Class

class Bird:
  def __init__(self,name,wings,fly=0):
    self.name = name
    self.wings = wings
    self.fly = fly
  def flight(self):
    return f"{self.name} have a wingspan of {self.wings} m and they can fly {self.fly} hours non-stop."

class Flightless(Bird):
  def __init__(self,name,wings):
    super().__init__(name,wings)
  def flight(self):
    return f"{self.name} is a flightless bird, have a wingspan of {self.wings}m."


#Function that demonstrate polymorphism
def air_flight(bird):
  print(bird.flight())

# %%
raven = Bird("Black Raven",0.02,6)
raven.flight()

# %%
ostrich = Flightless("Ostrich",2)
ostrich.flight()

# %%
air_flight(raven)
air_flight(ostrich)

# %%
#Polymorphism with functions and methods
#Base class

class Shape:
  def area(self):
    return "The area of the figure"

#Derived class 1
class Rectangle(Shape):
  def __init__(self,width,height):
    self.width = width
    self.height = height

  def area(self):
    return self.width*self.height

#Derived class 2
class Circle(Shape):
  def __init__(self,radius):
    self.radius = radius

  def area(self):
    return 3.14*self.radius*self.radius

#Function that demonstrates polymorphism
def print_area(shape):
  return f"The area is {shape.area()} m^2"

# %%
rectangle = Rectangle(4,5)
circle = Circle(2)

print(print_area(rectangle))
print(print_area(circle))

# %% [markdown]
# #### Interfaces
#
# It is called interfaces in other programming languages in Python it is acheived by Abstract Base classes (ABC)

# %% [markdown]
# #### Polymorphism with Abstract Base Classes
#
# Abstract Base Classes (ABCs) are used to define common methods for a group of related objects. They can enforce that derived classes implement particular methods, promoting consistency across different implementations.

# %%
from abc import ABC,abstractmethod

#Define an abstract class
class Vehicle(ABC):
  @abstractmethod
  def start_engine(self):
    pass    #since it is abstract, it needs to be empty

#Derived class 1
class Car(Vehicle):
  def start_engine(self):
    return "Car engine started."

#Derived class 2
class Motorcycle(Vehicle):
  def start_engine(self):
    return "Motorcycle engine started."

#Function that demonstrate polymorphism
def start_vehicle(vehicle):
  print(vehicle.start_engine())

#Create objects of car and motorcycle
car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
start_vehicle(motorcycle)

# %% [markdown]
# #### Conclusion Polymorphism
#
# Ploymorphism is a powerful feature of OOP that allows for flexibility and integration in code design. It enables a single function to handle objects of different classes, each with its own implementation of a method. By understanding and applying polymorphism, you can create more extensible and maintainable object-oriented programs.

# %% [markdown]
# #### Encapsulation and Abstraction
#
# Encapsulation and Abstraction are two fundamental principles in Object-Oriented Programming (OOP) that help in designing robust, maintainable, and reusable code. Encapsulation involves bundling data and methods that operate on the data within a single unit, while abstraction involves in hiding complex implementation details and exposing only the necessary features.

# %% [markdown]
# #### Encapsulation
#
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit. It restricts direct access to some of the object's components, which is means of preventing accidental interference and misuse of data.

# %%
# Encapsulation with Getter and Setter Methods
# Access variables : public, protected and private variables or access modifiers

class Person:
  def __init__(self,name,age):
    self.name = name    #public variable
    self.age = age    #public variable

def get_name(person):   #Able to access this particular name from outside the class
  return person.name


person = Person("Saim",25)
print(person.name)
get_name(person)

# %%
dir(person)

# %%
#Private variables

class Person:
  def __init__(self,name,age,gender):
    self.__name = name    #private variable
    self.__age = age    #private variable
    self.gender = gender  #public varibale

def get_name(person): #will not work a __name is private and it will not recognize the attribute
  return person.__name

person = Person("Sam",24,"Male")
# print(person.__name)
get_name(person)

# %%
dir(person)

# %%
#Protected variables

class Person:
  def __init__(self,name,age,gender):
    self._name = name    #protected variable
    self._age = age    #protected variable
    self.gender = gender  #public varibale

class Employee(Person):
  def __init__(self,name,age,gender):
    super().__init__(name,age,gender)

def get_name(employee): #will not work a __name is private and it will not recognize the attribute
  return employee._name

employee = Employee("John",21,"Male")
get_name(employee)

# %%
dir(employee)

# %%
# Encapsulation with Getter and Setter
class Person:
  def __init__(self,name,age):
    self.__name = name  #private variable or access modifier
    self.__age = age #private variable

  #Getter method for name
  def get_name(self):
    return self.__name

  #Setter method for age
  def set_name(self,name):
    self.__name = name

  #Getter method for age
  def get_age(self):
    return self.__age

  #Setter method for age
  def set_age(self,age):
    if age>0:
      self.__age = age
    else:
      print("Age cannot be negative.")

nokia = Person("Nokia",159)
#Access and modify private variables using getter and setter
print(nokia.get_name())
print(nokia.get_age())

nokia.set_name("Naman")
nokia.set_age(25)

print(nokia.get_name())
print(nokia.get_age())

# %%
dir(nokia)

# %%
#The modern Pythonic Way

class Person:
    def __init__(self, name, age):
        self._name = name
        self._age = age

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, value):
        self._name = value

    @property
    def age(self):
        return self._age

    @age.setter
    def age(self, value):
        if value > 0:
            self._age = value
        else:
            print("Age cannot be negative.")

alpha = Person("Sam",98)
print(alpha.name)

alpha.name = 'Tara'
print(alpha.name)

# %% [markdown]
# #### Abstraction
#
# Abstraction is the concpet of hiding complex implementation details and showing only the necessary features of an object. This helps in reducing programming complexity and effort.

# %%
from abc import ABC,abstractmethod

#Abstract Base Class
class Vehicle(ABC):
  def drive(self):
    print("the vehicle started and is moving.")

  @abstractmethod
  def start_engine(self):
    pass

class Car(Vehicle):
  def start_engine(self):
    print("Car engine is started.")

def operate_vehicle(vehicle):
  vehicle.start_engine()
  vehicle.drive()

car = Car()
operate_vehicle(car)

# %% [markdown]
# #### Magic Methods
#
# Magic methods in Python, also known as **dunder** methods (double underscore methods), are special methods that start and end with double underscores. These methods enable you to define the behaviour of objects for built-in operations, such as arithmetic operations, comparisions, and more.
#
#
# ### Magic Methods:
#
# Magic methods are predefined methods in Python that you can override to change the behaviour of your objects. Some common magic methods include:
# - \_\_init\_\_ : Initializes a new instance of a class.
# - \_\_str\_\_ : Returns a string representation of an object.
# - \_\_repr\_\_ : Returns an official string representation of an object.
# - \_\_len\_\_ : Returns the length of an object.
# - \_\_getitem\_\_ : Gets an item from a container.
# - \_\_setitem\_\_ : Sets an item in a container.

# %%
dir(nokia) #Shows the methods that are relevant to that specific object's type

# %%
print(nokia)

# %%
#We can override these magic functions also
#Basic methods
class Fruit:
  def __init__(self,name,rate):
    self.name = name
    self.rate = rate

  def __str__(self):      #Here, I just override the __str__ method
    return f"{self.name} is {self.rate} Rs per kg"

  def __repr__(self):
    return f"{self.name}, {self.rate}"

apple = Fruit("Apple",150)
print(apple)
print(repr(apple))

# %% [markdown]
# #### Operator Overloading
#
# Operator overloading allows you to define the behaviour of operators(+,-,*,etc.) for custom objects. You acheive this by overriding specific magic method in your class.
#
# Common operator overloading magic methods.
# - \_\_add\_\_(self,other) : Adds two objects using the + operator.
# - \_\_sub\_\_(self,other) : Substracts two objects using the - opertor.
# - \_\_mul\_\_(self,other) : Multiplies two objects using the * operator.
# - \_\_truediv\_\_(self,other) : Divides two objects using the / operator.
# - \_\_eq\_\_(self,other) : Checks if two objects are equal using the == operator.
# - \_\_lt\_\_(self,other) : Checks if one object is less than another using < operator.
# - \_\_gt\_\_(self,other) : Checks if one object is greater than another using > operator.

# %%
1+1 #We can override such operators

# %%
#Mathematical operation for vectors

class Vector:
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def __add__(self,other):
    return Vector(self.x + other.x, self.y + other.y)

  def __sub__(self,other):
    return Vector(self.x - other.x, self.y - other.y)

  def __mul__(self,other):
    return Vector(self.x * other.x, self.y * other.y)

  def __eq__(self,other):
    return self.x == other.x and self.y == other.y

  def __repr__(self):
    return f"Vector({self.x}, {self.y})"

#Create objects of the vector class
v1 = Vector(2,3)
v2 = Vector(4,5)

# %%
print(v1+v2)
print(v1-v2)
print(v1*v2)
print(v1==v2)
print(v1)

# %%
#Overloading operators for complex numbers

class ComplexNumber:
  def __init__(self,real,imag):
    self.real = real
    self.imag = imag

  def __add__(self,other):
    return ComplexNumber(self.real + other.real, self.imag + other.imag)

  def __sub__(self,other):
    return ComplexNumber(self.real - other.real, self.imag - other.imag)

  def __mul__(self,other):
    real_part = self.real * other.imag - self.imag * other.imag
    imag_part = self.real * other.imag + self.imag * other.real
    return ComplexNumber(real_part,imag_part)

  def __truediv__(self,other):
    denominator = other.real ** 2 + other.imag ** 2
    real_part = (self.real * other.real + self.imag * other.imag) / denominator
    imag_part = (self.imag * other.real + self.real * other.imag) / denominator
    return ComplexNumber(real_part,imag_part)

  def __eq__(self,other):
    return self.real == other.real  and self.imag == other.imag

  def __repr__(self):
    return f"{self.real} + {self.imag}i"

#Create objects of complex numbern class
c1 = ComplexNumber(2,3)
c2 = ComplexNumber(1,4)

# %%
print(c1+c2)
print(c1-c2)
print(c1*c2)
print(c1==c2)
print(repr(c1))

# %% [markdown]
# #### Custom Exception (Raise and Throw an Exception)

# %%
class Error(Exception):
  pass

class dobException(Error):
  pass

year = int(input("Enter your DOB: "))
age = 2025 - year

try:
  if age<=30 and age>=20:
    print("The age is valid, you can apply for exams.")
  else:
    raise dobException
except dobException:
  print("Sorry, your age is not within the desired values.")

# %% [markdown]
# #### Iterators
#
# Iterators are advanced Python concepts that allow for efficient looping and memory management. Iterators provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
my_list = [1,2,3,4,5,6]
for i in my_list:
  print(i)

# %%
print(type(my_list))
print(my_list)

# %%
#Iterator
iterator = iter(my_list)
print(type(iterator))

# %%
iterator

# %%
# Iterator uses lazy loading technique
# lazy loading in an iterator is a technique where the values of a sequence are not computed or stored in memory all at once.
# Instead, they are generated one at a time, only when explicitly requested by an iterating process (like a for loop or the next() function).
# This approach is also known as "lazy evaluation".

# Iterate through all elements

try:
  print(next(iterator))
except StopIteration:
  print("All the elements are iterated.")

# %%
#String iterator
my_string = "Hello"
print(my_string)
str_iterator = iter(my_string)

# %%
try:
  print(next(str_iterator))
except StopIteration:
  print("All the elements are iterated.")

# %% [markdown]
# #### Generators
#
# Generators are a simpler way to create iterators. They use the yield keyword to produce a series of values lazily, which means they generate values on the fly and do not store them in memory.

# %%
def square(n):
  for i in range(n):
    yield i**2

# %%
square(3)

# %%
square(5)

# %%
for i in square(5):
  print(i)

# %%
sq = square(4)
sq

# %%
try:
  print(next(sq))
except StopIteration:
  print("All elements iterated.")

# %%
def my_generator():
  yield 1
  yield 2
  yield 3

# %%
gen = my_generator()
gen

# %%
for val in gen:
  print(val)

# %% [markdown]
# #### Practical Example generator : Reading large files
#
# Generators are particularly useful for reading large files because they allow you to process one line at a time without loading the entire file into memory.

# %%
#Practical: Reading large files

def read_large_file(file_path):
  with open(file_path,'r') as file:
    for line in file:
      yield line

# %%
file_path = "/content/large.txt"

for line in read_large_file(file_path):
  print(line.strip())

# %% [markdown]
# #### Decorators
#
# Decorators are powerful and flexible feature in python that allows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code. This lesson covers the basic of decorators, including how to create and use them.

# %%
### function copy
### closures
### decorators

# %%
## function copy
def welcome():
  return "Welcome to advance python"

welcome()

# %%
wel = welcome   #function copy
print(wel())

del welcome
print(wel())

# %%
## closures

def main_welcome():
  name = "Saim"         #also could have been added in argument : main_welcome(name)

  def sub_welcome_method():
    print("Welcome to the advance python course.")
    print(name)
    print("Please learn these concepts properly.")

  return sub_welcome_method()

# %%
main_welcome()

# %%
def main_welcome(func,lst):

  def sub_welcome_method():
    print("Welcome to the advance python course.")
    print(func(lst))
    print("Please learn these concepts properly.")
  return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])

# %%
## Decorator
def main_welcome(func):

  def sub_welcome_method():
    print("Welcome to the advance python course.")
    func()
    print("Please learn these concepts properly.")
  return sub_welcome_method()

# %%
def course_introduction():
  print("This is an advance python course.")

course_introduction()

# %%
main_welcome(course_introduction)

# %%
@main_welcome
def course_introduction():
  print("This is an advance python course.")

# %%
# Decorator

def my_decorator(func):
  def wrapper():
    print("Something is happening before the function is called.")
    func()
    print("Something is happening after the function is called.")
  return wrapper

# %%
@my_decorator
def say_hello():
  print("Helloo")

# %%
say_hello()

# %%
## Decorators with arguments

def repeat(n):
  def decorator(func):
    def wrapper(*args,**kwargs):
      for _ in range(n):
        func(*args,**kwargs)
    return wrapper
  return decorator

# %%
@repeat(3)
def say_hello():
  print("Hello")

# %%
say_hello()

# %% [markdown]
# #### Conclusion Decorators
#
# Decorators are a powerful tool in Python for extending and modifying the behaviour of functions and methods. They provide a clean and readable way to add functionality such as logging, timing, access control, and more without changing the original code. Uderstanding and using decorators effectively can significantly enhance your Python programming skills.

# %% [markdown]
# ---
